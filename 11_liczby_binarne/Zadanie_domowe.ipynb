# %% [markdown]
# ## Zamień liczbę "37" oraz liczbę tworzoną przez dwie ostatnie cyfry z numeru indeksu na liczby binarne, a następnie dodaj, odejmij (mniejszą od większej) i pomnóż je przez siebie (ręcznie). Prześlij zdjęcie rozwiązań, lub printscreen z edytora graficznego.

# %% [markdown]
# nr indeksu: 473701

# %%
print(bin(37))
print(bin(1))
print(bin(40))
# Out:
# 0b100101
# 0b1
# 0b101000

# %% [markdown]
# ![bin.png](attachment:bin.png)
